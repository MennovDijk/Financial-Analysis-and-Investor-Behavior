# %%
from keras.optimizers import SGD, RMSprop, Adam
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.utils import plot_model
from sklearn.metrics import mean_squared_error, mean_absolute_error
from keras import backend as K
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import matplotlib.pyplot as plt
import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'

# %%
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1))

# %%
df = pd.read_excel("returns.xlsx")
df = df.iloc[:-3]
df_copy = df.copy()

for c in df.columns:
    df["volatility_"+c] = (df[c].rolling(20).std())*np.sqrt(52)

# %%
df_train = df[20:167]
df_test = df[197:]

# %% [markdown]
# # Why is this so difficult to find lel

# %%
# model.predict(np.array([test_X[-1],]))

# %%
def fit_model(train_X, train_y, test_X, test_y):
    model = Sequential()

    model.add(Dense(20)) 
    model.add(Activation("relu"))

    model.add(Dense(40)) 
    model.add(Activation("relu"))

    model.add(Dense(10))
    model.add(Activation("relu"))
    model.add(Dense(1))

    model.add(Activation('linear'))

    # Compile and Run
    model.compile(loss= root_mean_squared_error, optimizer = Adam()) # Try SGD, adam, adagrad and compare!!!
    model.fit(train_X, train_y, epochs = 50, batch_size = 1, verbose=1)
    
    yhat = model.predict(test_X)
    fp = model.predict(np.array([test_X[-1],])) # <-- finally
    
    return yhat, test_y, fp

# %%
results = {}
final_predictions = {}
for c in df_copy.columns:
    print(c)
    
    train_y = df_train["volatility_"+c].shift(1)[1:].values.astype("float32")
    test_y =  df_test["volatility_"+c].shift(1)[1:].values.astype("float32")


    train_X = df_train.iloc[:,19:].shift(-1)[:-1]
    train_X[c] = df_train[c].shift(-1)[:-1]

    test_X =  df_test.iloc[:,19:].shift(-1)[:-1]
    test_X[c] = df_test[c].shift(-1)[:-1]

    train_X = train_X.values.astype("float32")
    test_X = test_X.values.astype("float32")

    yhat, test_y, fp = fit_model(train_X, train_y, test_X, test_y)
    
    results[c] = [yhat,test_y]
    final_predictions[c] = fp # historical average or one period oos?
    
    print("="*100)
# Out:
# ALL
# Epoch 1/50
# 146/146 [==============================] - 1s 7ms/step - loss: 0.0161
# Epoch 2/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0101
# Epoch 3/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0079
# Epoch 4/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0088
# Epoch 5/50
# 146/146 [==============================] - 1s 3ms/step - loss: 0.0086
# Epoch 6/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 7/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0082
# Epoch 8/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0081
# Epoch 9/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 10/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 11/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 12/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 13/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0080
# Epoch 14/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0085
# Epoch 15/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0071
# Epoch 16/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0077
# Epoch 17/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0091
# Epoch 18/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 19/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 20/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 21/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 22/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 23/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0068
# Epoch 24/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 25/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0069
# Epoch 26/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 27/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 28/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0063
# Epoch 29/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0079
# Epoch 30/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0075
# Epoch 31/50
# 146/146 [==============================] - 1s 3ms/step - loss: 0.0074
# Epoch 32/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 33/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 34/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 35/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 36/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 37/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0077
# Epoch 38/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 39/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 40/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0068
# Epoch 41/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 42/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 43/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0068
# Epoch 44/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0068
# Epoch 45/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 46/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0068
# Epoch 47/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 48/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0062
# Epoch 49/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 50/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0060
# ==================================================
# SMALL
# Epoch 1/50
# 146/146 [==============================] - 1s 7ms/step - loss: 0.0160
# Epoch 2/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0139
# Epoch 3/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 4/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0134
# Epoch 5/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0111
# Epoch 6/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0118
# Epoch 7/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0113
# Epoch 8/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0129
# Epoch 9/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0094
# Epoch 10/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0121
# Epoch 11/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0108
# Epoch 12/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0094
# Epoch 13/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0100
# Epoch 14/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0084
# Epoch 15/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0088
# Epoch 16/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0091
# Epoch 17/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0084
# Epoch 18/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0095
# Epoch 19/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0084
# Epoch 20/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0088
# Epoch 21/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0083
# Epoch 22/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0080
# Epoch 23/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0083
# Epoch 24/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0084
# Epoch 25/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 26/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 27/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0083
# Epoch 28/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0077
# Epoch 29/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0077
# Epoch 30/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0081
# Epoch 31/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 32/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 33/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 34/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 35/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0084
# Epoch 36/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 37/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 38/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0083
# Epoch 39/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 40/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 41/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0080
# Epoch 42/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0069
# Epoch 43/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0069
# Epoch 44/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0069
# Epoch 45/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0075
# Epoch 46/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0069
# Epoch 47/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 48/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0069
# Epoch 49/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0081
# Epoch 50/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0063
# ==================================================
# VALUE
# Epoch 1/50
# 146/146 [==============================] - 1s 7ms/step - loss: 0.0263
# Epoch 2/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0114
# Epoch 3/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0092
# Epoch 4/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0088
# Epoch 5/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0089
# Epoch 6/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0088
# Epoch 7/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0081
# Epoch 8/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0088
# Epoch 9/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0083
# Epoch 10/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 11/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0104
# Epoch 12/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0098
# Epoch 13/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0083
# Epoch 14/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0081
# Epoch 15/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0076
# Epoch 16/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 17/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0081
# Epoch 18/50
# 146/146 [==============================] - 1s 3ms/step - loss: 0.0083
# Epoch 19/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0083
# Epoch 20/50
# 146/146 [==============================] - 1s 3ms/step - loss: 0.0086
# Epoch 21/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0080
# Epoch 22/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0083
# Epoch 23/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0077
# Epoch 24/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0082
# Epoch 25/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 26/50
# 146/146 [==============================] - 1s 3ms/step - loss: 0.0074
# Epoch 27/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0077
# Epoch 28/50
# 146/146 [==============================] - 1s 3ms/step - loss: 0.0083
# Epoch 29/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0065
# Epoch 30/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0076
# Epoch 31/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0075
# Epoch 32/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0083
# Epoch 33/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0073A: 0s - loss
# Epoch 34/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 35/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 36/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0083
# Epoch 37/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0067
# Epoch 38/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0082
# Epoch 39/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0079
# Epoch 40/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0074
# Epoch 41/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 42/50
# 146/146 [==============================] - 1s 3ms/step - loss: 0.0066
# Epoch 43/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 44/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 45/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0076
# Epoch 46/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 47/50
# 146/146 [==============================] - 1s 3ms/step - loss: 0.0074
# Epoch 48/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 49/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0077
# Epoch 50/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0068
# ==================================================
# Europe
# Epoch 1/50
# 146/146 [==============================] - 1s 8ms/step - loss: 0.0634
# Epoch 2/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0340
# Epoch 3/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0299A: 0s - loss
# Epoch 4/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0255
# Epoch 5/50
# 146/146 [==============================] - 1s 3ms/step - loss: 0.0229
# Epoch 6/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0215
# Epoch 7/50
# 146/146 [==============================] - 1s 3ms/step - loss: 0.0201
# Epoch 8/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0188
# Epoch 9/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0178
# Epoch 10/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0179
# Epoch 11/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0173
# Epoch 12/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0182
# Epoch 13/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0152
# Epoch 14/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0140
# Epoch 15/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 16/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0134
# Epoch 17/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0132
# Epoch 18/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0135
# Epoch 19/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0117
# Epoch 20/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0118
# Epoch 21/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0112
# Epoch 22/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0102
# Epoch 23/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0116
# Epoch 24/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0119
# Epoch 25/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0105
# Epoch 26/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0104
# Epoch 27/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0105
# Epoch 28/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0111
# Epoch 29/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0096
# Epoch 30/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0099
# Epoch 31/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0093
# Epoch 32/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0091
# Epoch 33/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0103
# Epoch 34/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0098
# Epoch 35/50
# 146/146 [==============================] - 1s 3ms/step - loss: 0.0104
# Epoch 36/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0112
# Epoch 37/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0103
# Epoch 38/50
# 146/146 [==============================] - 1s 3ms/step - loss: 0.0095
# Epoch 39/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0092
# Epoch 40/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0090
# Epoch 41/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0090
# Epoch 42/50
# 146/146 [==============================] - 1s 7ms/step - loss: 0.0094
# Epoch 43/50
# 146/146 [==============================] - 1s 6ms/step - loss: 0.0087
# Epoch 44/50
# 146/146 [==============================] - 1s 6ms/step - loss: 0.0100
# Epoch 45/50
# 146/146 [==============================] - 1s 6ms/step - loss: 0.0099
# Epoch 46/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0090
# Epoch 47/50
# 146/146 [==============================] - 1s 6ms/step - loss: 0.0100
# Epoch 48/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0097
# Epoch 49/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0093
# Epoch 50/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0102
# ==================================================
# US
# Epoch 1/50
# 146/146 [==============================] - 1s 9ms/step - loss: 0.0352
# Epoch 2/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0138
# Epoch 3/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0114A: 0s - lo
# Epoch 4/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0133
# Epoch 5/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0113
# Epoch 6/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0094
# Epoch 7/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0091
# Epoch 8/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0089
# Epoch 9/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0086
# Epoch 10/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0099
# Epoch 11/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0076
# Epoch 12/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0082
# Epoch 13/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0073A: 0s - l
# Epoch 14/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0074
# Epoch 15/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0074
# Epoch 16/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0072
# Epoch 17/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0077
# Epoch 18/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0074
# Epoch 19/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0081
# Epoch 20/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0070
# Epoch 21/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0068A: 0s -
# Epoch 22/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0072
# Epoch 23/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0071
# Epoch 24/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0069
# Epoch 25/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0063
# Epoch 26/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0078
# Epoch 27/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0069
# Epoch 28/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0064
# Epoch 29/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0062
# Epoch 30/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0076
# Epoch 31/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0063
# Epoch 32/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0067
# Epoch 33/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0065
# Epoch 34/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0067
# Epoch 35/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0075
# Epoch 36/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0070
# Epoch 37/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0065
# Epoch 38/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0064
# Epoch 39/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0067
# Epoch 40/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0067
# Epoch 41/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0062
# Epoch 42/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0060
# Epoch 43/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0059
# Epoch 44/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0066
# Epoch 45/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0070
# Epoch 46/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0063
# Epoch 47/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0063
# Epoch 48/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0061
# Epoch 49/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0057
# Epoch 50/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0057
# ==================================================
# Japan
# Epoch 1/50
# 146/146 [==============================] - 1s 10ms/step - loss: 0.0294
# Epoch 2/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0171
# Epoch 3/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0157
# Epoch 4/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0146
# Epoch 5/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0138
# Epoch 6/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0136
# Epoch 7/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0116
# Epoch 8/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0107
# Epoch 9/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0107
# Epoch 10/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0120
# Epoch 11/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0102
# Epoch 12/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0101
# Epoch 13/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0106
# Epoch 14/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0108
# Epoch 15/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0101
# Epoch 16/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0109
# Epoch 17/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0112
# Epoch 18/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0086
# Epoch 19/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0099A: 0s - lo
# Epoch 20/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0099
# Epoch 21/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0105
# Epoch 22/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0096
# Epoch 23/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0106A: 0s - l
# Epoch 24/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0097
# Epoch 25/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0087
# Epoch 26/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0103
# Epoch 27/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0101
# Epoch 28/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0080
# Epoch 29/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0089
# Epoch 30/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0098
# Epoch 31/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0090
# Epoch 32/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0090
# Epoch 33/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0099
# Epoch 34/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0087
# Epoch 35/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0094
# Epoch 36/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0088
# Epoch 37/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0098
# Epoch 38/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0085
# Epoch 39/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0092
# Epoch 40/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0102
# Epoch 41/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0089
# Epoch 42/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0088
# Epoch 43/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0086
# Epoch 44/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0080
# Epoch 45/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0085
# Epoch 46/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0083
# Epoch 47/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0086
# Epoch 48/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0080
# Epoch 49/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0089
# Epoch 50/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0083
# ==================================================
# Emerging M
# Epoch 1/50
# 146/146 [==============================] - 1s 9ms/step - loss: 0.0393
# Epoch 2/50
# 146/146 [==============================] - 1s 3ms/step - loss: 0.0216
# Epoch 3/50
# 146/146 [==============================] - 1s 3ms/step - loss: 0.0176
# Epoch 4/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0159
# Epoch 5/50
# 146/146 [==============================] - 1s 3ms/step - loss: 0.0140
# Epoch 6/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0146
# Epoch 7/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0128
# Epoch 8/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0129
# Epoch 9/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0134
# Epoch 10/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0112
# Epoch 11/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0126
# Epoch 12/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0106
# Epoch 13/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0110
# Epoch 14/50
# 146/146 [==============================] - 1s 7ms/step - loss: 0.0111
# Epoch 15/50
# 146/146 [==============================] - 1s 7ms/step - loss: 0.0095
# Epoch 16/50
# 146/146 [==============================] - 1s 6ms/step - loss: 0.0100
# Epoch 17/50
# 146/146 [==============================] - 1s 5ms/step - loss: 0.0116
# Epoch 18/50
#  11/146 [=>............................] - ETA: 0s - loss: 0.008
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-498388373d6e> in <module>()
#      16     test_X = test_X.values.astype("float32")
#      17
# ---> 18     yhat, test_y, fp = fit_model(train_X, train_y, test_X, test_y)
#      19
#      20     results[c] = [yhat,test_y]
#
# <ipython-input-60-c95166dac59d> in fit_model(train_X, train_y, test_X, test_y)
#      16     # Compile and Run
#      17     model.compile(loss= root_mean_squared_error, optimizer = Adam()) # Try SGD, adam, adagrad and compare!!!
# ---> 18     model.fit(train_X, train_y, epochs = 50, batch_size = 1, verbose=1)
#      19
#      20     yhat = model.predict(test_X)
#
# ~\AppData\Local\Programs\Python\Python35\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1040                                         initial_epoch=initial_epoch,
#    1041                                         steps_per_epoch=steps_per_epoch,
# -> 1042                                         validation_steps=validation_steps)
#    1043
#    1044     def evaluate(self, x=None, y=None,
#
# ~\AppData\Local\Programs\Python\Python35\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     203                     batch_logs[l] = o
#     204
# --> 205                 callbacks.on_batch_end(batch_index, batch_logs)
#     206                 if callback_model.stop_training:
#     207                     break
#
# ~\AppData\Local\Programs\Python\Python35\lib\site-packages\keras\callbacks.py in on_batch_end(self, batch, logs)
#     111         t_before_callbacks = time.time()
#     112         for callback in self.callbacks:
# --> 113             callback.on_batch_end(batch, logs)
#     114         self._delta_ts_batch_end.append(time.time() - t_before_callbacks)
#     115         delta_t_median = np.median(self._delta_ts_batch_end)
#
# ~\AppData\Local\Programs\Python\Python35\lib\site-packages\keras\callbacks.py in on_batch_end(self, batch, logs)
#     326         # will be handled by on_epoch_end.
#     327         if self.verbose and self.seen < self.target:
# --> 328             self.progbar.update(self.seen, self.log_values)
#     329
#     330     def on_epoch_end(self, epoch, logs=None):
#
# ~\AppData\Local\Programs\Python\Python35\lib\site-packages\keras\utils\generic_utils.py in update(self, current, values)
#     354             prev_total_width = self._total_width
#     355             if self._dynamic_display:
# --> 356                 sys.stdout.write('\b' * prev_total_width)
#     357                 sys.stdout.write('\r')
#     358             else:
#
# ~\AppData\Local\Programs\Python\Python35\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     382                     self.flush()
#     383             else:
# --> 384                 self._schedule_flush()
#     385
#     386     def writelines(self, sequence):
#
# ~\AppData\Local\Programs\Python\Python35\lib\site-packages\ipykernel\iostream.py in _schedule_flush(self)
#     323         def _schedule_in_thread():
#     324             self._io_loop.call_later(self.flush_interval, self._flush)
# --> 325         self.pub_thread.schedule(_schedule_in_thread)
#     326
#     327     def flush(self):
#
# ~\AppData\Local\Programs\Python\Python35\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# ~\AppData\Local\Programs\Python\Python35\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     389                                  copy_threshold=self.copy_threshold)
#     390             data.group = group
# --> 391         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     392
#     393     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\AppData\Local\Programs\Python\Python35\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
# yhat = model.predict(test_X)
# print(mean_absolute_error(yhat, test_y))

# %%
# print(test_y)

# %%
# yhat

# %%
# plt.plot(yhat[40:50], "g", label = "predicted")
# plt.plot(test_y[40:50], "r", label = "real")
# plt.legend()
# plt.show()
